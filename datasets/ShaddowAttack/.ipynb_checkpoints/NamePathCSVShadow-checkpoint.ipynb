# %%
import glob
import os

# Get a sorted list of filenames

colors  = { 0:'red', 1:'blue', 2:'yellow', 3:'black'}
Shapes  = { 0:'triangle', 1:'circle', 2:'diamond', 3:'octagon', 4:'inverse triangle'}
Symbols = { 0:'digit', 1:'text', 2:'cross', 3:'pedestrian', 4:'bicycle', 5:'animal',  6:'blank', 7:'car', 8:'caution', 9:'light', 10: 'rectangle', 11:'snowflake', 12:'ArrowL', 13:'ArrowR', 14:'bump', 15:'arrow', 16:'van', 17:'roundabout', 18:'doublecurve', 19:'narrowR'}          


# worker R_arrow L_arrow S_arrow bump snowflake roundabout, forbidden lines,
# warning: addedLane, curveRight, dip, intersection, laneEnds, merge, pedestrianCrossing, signalAhead, slow, stopAhead, thruMergeLeft, thruMergeRight, turnLeft, turnRight, yieldAhead
# prohibition: doNotPass, keepRight, rightLaneMustTurn, 
    
path  = 'datasets/train'
pathtest = 'datasets/test'
# Out_path = 'train.csv'

subdirectories = ['test'] + [f for f in os.listdir(path) if os.path.isdir(os.path.join(path, f))] 
print('subdirectories',subdirectories)


# filenames = sorted(glob.glob('Train/*.png'))
# filenames = sorted(glob.glob(In_path))

for subdirectory in subdirectories:
    if subdirectory == 'test':
        dataset_folder = os.path.join(pathtest)
        images_folder  = os.path.join(pathtest, 'images')
    else:
        dataset_folder = os.path.join(path, f'{subdirectory}')
        images_folder = os.path.join(dataset_folder, 'images')


    input_path = os.path.join(images_folder, '*.png')
    output_path = os.path.join(dataset_folder, f'{subdirectory}.csv')
    # print('output_path',output_path)

    if os.path.exists(output_path):
        os.remove(output_path)
    filenames = sorted(glob.glob(input_path))

    # Open the file for writing
    # with open('Train.csv', 'w') as f:
    with open(output_path, 'w') as f:
        # Write the header line with column names
        f.write("File Path, Class ID, Shape ID, Color ID, Symbol ID\n")
        
        # Write the sorted filenames along with color and shape IDs
        for file in filenames:
            # Extract the filename without the extension
            base_filename = os.path.splitext(os.path.basename(file))[0]
            
            # Check if the 4th digit of the filename is '1'
            if base_filename[3] == '0' and base_filename[4] == '0':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 0
            if base_filename[3] == '0' and base_filename[4] == '1':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 1
            if base_filename[3] == '0' and base_filename[4] == '2':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 2
            if base_filename[3] == '0' and base_filename[4] == '3':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 3
            if base_filename[3] == '0' and base_filename[4] == '4':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 4
            if base_filename[3] == '0' and base_filename[4] == '5':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 5
            if base_filename[3] == '0' and base_filename[4] == '6':
                color_id = 3
                shape_id = 1
                symbol_id = 0
                class_Id = 6
            if base_filename[3] == '0' and base_filename[4] == '7':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 7        
            
            if base_filename[3] == '0' and base_filename[4] == '8':
                color_id = 0
                shape_id = 1
                symbol_id = 0
                class_Id = 8        
            if base_filename[3] == '0' and base_filename[4] == '9':
                color_id = 0
                shape_id = 1
                symbol_id = 7
                class_Id = 9        
            if base_filename[3] == '1' and base_filename[4] == '0':
                color_id = 0
                shape_id = 1
                symbol_id = 7
                class_Id = 10        
                  
            elif base_filename[3] == '1' and base_filename[4] == '1':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0   
                symbol_id = 2            
                class_Id = 11
            elif base_filename[3] == '1' and base_filename[4] == '2':
                # Set default values if the condition is not met
                color_id = 2   
                shape_id = 2    
                symbol_id = 2            
                symbol_id = 6                        
                class_Id = 12
            elif base_filename[3] == '1' and base_filename[4] == '3':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 4   
                symbol_id = 6            
                class_Id = 13
            elif base_filename[3] == '1' and base_filename[4] == '4':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 3   
                symbol_id = 1             
                class_Id = 14
            elif base_filename[3] == '1' and base_filename[4] == '5':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 1   
                symbol_id = 6             
                class_Id = 15
            elif base_filename[3] == '1' and base_filename[4] == '6':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 1   
                symbol_id = 16             
                class_Id = 16            
            elif base_filename[3] == '1' and base_filename[4] == '7':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 1  
                symbol_id = 10             
                class_Id = 17 
            elif base_filename[3] == '1' and base_filename[4] == '8':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 8             
                class_Id = 18 
            elif base_filename[3] == '1' and base_filename[4] == '9':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 12             
                class_Id = 19 
    
            elif base_filename[3] == '2' and base_filename[4] == '0':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 13             
                class_Id = 20 
    
            elif base_filename[3] == '2' and base_filename[4] == '1':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 18             
                class_Id = 21 
    
            elif base_filename[3] == '2' and base_filename[4] == '2':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 14             
                class_Id = 22 
    
            elif base_filename[3] == '2' and base_filename[4] == '3':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 7             
                class_Id = 23 
    
            elif base_filename[3] == '2' and base_filename[4] == '4':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 19             
                class_Id = 24 
    
            elif base_filename[3] == '2' and base_filename[4] == '5':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 3             
                class_Id = 25 
    
            elif base_filename[3] == '2' and base_filename[4] == '6':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0  
                symbol_id = 9             
                class_Id = 26 
    
    
            
            elif base_filename[3] == '2' and base_filename[4] == '7':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0   
                symbol_id = 3            
                class_Id = 27
            elif base_filename[3] == '2' and base_filename[4] == '8':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0   
                symbol_id = 3            
                class_Id = 28
            elif base_filename[3] == '2' and base_filename[4] == '9':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0   
                symbol_id = 4            
                class_Id = 29            
            elif base_filename[3] == '3' and base_filename[4] == '0':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0   
                symbol_id = 11            
                class_Id = 30
       
            elif base_filename[3] == '3' and base_filename[4] == '1':
                # Set default values if the condition is not met
                color_id = 0   
                shape_id = 0   
                symbol_id = 5            
                class_Id = 31
    
            elif base_filename[3] == '3' and base_filename[4] == '2':
                # Set default values if the condition is not met
                color_id = 3   
                shape_id = 1   
                symbol_id = 6            
                class_Id = 32
    
            elif base_filename[3] == '3' and base_filename[4] == '3':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 13            
                class_Id = 33
    
            elif base_filename[3] == '3' and base_filename[4] == '4':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 12            
                class_Id = 34
    
            elif base_filename[3] == '3' and base_filename[4] == '5':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 15            
                class_Id = 35
            elif base_filename[3] == '3' and base_filename[4] == '6':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 13            
                class_Id = 36
    
            elif base_filename[3] == '3' and base_filename[4] == '7':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 12            
                class_Id = 37
    
            elif base_filename[3] == '3' and base_filename[4] == '8':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 15            
                class_Id = 38
            elif base_filename[3] == '3' and base_filename[4] == '9':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 15            
                class_Id = 39
    
            elif base_filename[3] == '4' and base_filename[4] == '0':
                # Set default values if the condition is not met
                color_id = 1   
                shape_id = 1   
                symbol_id = 17            
                class_Id = 40
    
            elif base_filename[3] == '4' and base_filename[4] == '1':
                # Set default values if the condition is not met
                color_id = 3   
                shape_id = 1   
                symbol_id = 7            
                class_Id = 41
    
            elif base_filename[3] == '4' and base_filename[4] == '2':
                # Set default values if the condition is not met
                color_id = 3   
                shape_id = 1   
                symbol_id = 7            
                class_Id = 42
    
    
    
            
                # Write the data to the CSV file
            f.write(f"{file}, {class_Id}, {shape_id}, {color_id}, {symbol_id}\n")
# Out:
# subdirectories ['test', 'dataset_5', 'dataset_50', 'dataset_100', 'dataset_20', 'dataset_10', "['.DS_Store', 'images']", 'dataset_150']

# %%
import glob
import os

pathtestattacks = 'datasets/test-attacks/All'
# filenames = sorted(glob.glob(os.path.join(pathtestattacks, '*.png' )))

# print(len(filenames))
output_path     = 'datasets/test-attacks/test-attacks.csv'

color_id = 0   
shape_id = 3   
symbol_id = 1             
class_Id = 14



            
with open(output_path, 'w') as f:
    f.write("File Path, Class ID, Shape ID, Color ID, Symbol ID\n")
    for file in sorted(glob.glob(os.path.join(pathtestattacks, '*.png' ))):
        f.write(f"{file}, {class_Id}, {shape_id}, {color_id}, {symbol_id}\n")
    for file in sorted(glob.glob(os.path.join(pathtestattacks, '*.jpeg' ))):
        f.write(f"{file}, {class_Id}, {shape_id}, {color_id}, {symbol_id}\n")
    for file in sorted(glob.glob(os.path.join(pathtestattacks, '*.jpg' ))):
        f.write(f"{file}, {class_Id}, {shape_id}, {color_id}, {symbol_id}\n")
